# %%
# !pip install ultralytics -q

# %%
# !yolo detect predict model=yolov8m.pt source = './IMG_6566.mov'
# Out:
# Ultralytics YOLOv8.0.133  Python-3.7.6 torch-1.13.1+cpu CPU
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients
#
# video 1/1 (1/1385) C:\Users\22047063g\OneDrive\darknet\ball.mp4: 384x640 2 persons, 290.1ms
# video 1/1 (2/1385) C:\Users\22047063g\OneDrive\darknet\ball.mp4: 384x640 1 person, 227.0ms
# video 1/1 (3/1385) C:\Users\22047063g\OneDrive\darknet\ball.mp4: 384x640 1 person, 231.0ms
# video 1/1 (4/1385) C:\Users\22047063g\OneDrive\darknet\ball.mp4: 384x640 1 person, 225.0ms
# video 1/1 (5/1385) C:\Users\22047063g\OneDrive\darknet\ball.mp4: 384x640 2 persons, 209.0ms
# video 1/1 (6/1385) C:\Users\22047063g\OneDrive\darknet\ball.mp4: 384x640 1 person, 225.0ms
# video 1/1 (7/1385) C:\Users\22047063g\OneDrive\darknet\ball.mp4: 384x640 1 person, 227.0ms
# video 1/1 (8/1385) C:\Users\22047063g\OneDrive\darknet\ball.mp4: 384x640 1 person, 228.0ms
# video 1/1 (9/1385) C:\Users\22047063g\OneDrive\darknet\ball.mp4: 384x640 1 person, 216.0ms
# ...

# %%
# !ffmpeg -i {'./IMG_6566.mov'} -vcodec libx264 {'result.mp4'}
# Out:
# 'ffmpeg' is not recognized as an internal or external command,
# operable program or batch file.
